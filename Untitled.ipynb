# %%
import pandas as pd

# %%
a = pd.read_csv("sampled_1.csv")

# %%
b = pd.read_csv("trip_fare_1.csv")
b
# Out:
#                                  medallion                      hack_license  \
# 0         89D227B655E5C82AECF13C3F540D4CF4  BA96DE419E711691B9445D6A6307C170
# 1         0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 2         0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 3         DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4         DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# ...                                    ...                               ...
# 14776610  B33E71CD9E8FE1BE3B70FEB6E807DD15  BAF57796E45D921BB23217E17A372FF6
# 14776611  ED160B76D5349C8AC1ECF22CD4B8D538  3B93F6DA5DEBDE9560993FA624C4FF76
# 14776612  D83F9AC0E33F6F19869C243BE6AB6FE5  85A55B6772275374EF90AC9457DC1F83
# 14776613  04E59442A7DDBCE515E33CD355D866E7  7913172189931A1A1632562B10AB53C4
# 14776614  D30BED60331C79E3F7ACD05B325ED42F  B5E1D2461A5BCC8819188DACEC17CD69
#
# ...

# %%
a
# Out:
#                                medallion                      hack_license  \
# 0       4BAD9258F80F0557C351A1765B209298  44B47A8DA1F1543C803FFBFAB9A96412
# 1       EF0AE8B6BBD239B3424741BAB551C179  C12D7B322897E41D27B3981E036B2D47
# 2       4ECDC17413FB05BFDD0BA837C7D657EF  E39FFA7A2F91E5BD08B716832EA8112A
# 3       CA5B90CD7F0B61A0C32ABBCF3E1B1D73  A999EF8A46251492437FDA23C8F7DF3C
# 4       113D28C6EF6F520407B47F9C97580A3B  5852E74E3414B115D64C49B3D3ADB416
# ...                                  ...                               ...
# 738826  4591B5DD928BB1A9444B706425BECD8F  378F34F93043BC8CB5C92186819B2FD2
# 738827  40CE9601A3E4406427BC3799A4258CC7  63F78C93C7ABA820DE182CB864148191
# 738828  90444DF112C5770C8C82DE2A7930C69B  5594F56B961F941D7AE7AD5AB3C33442
# 738829  AA105C297823E6DA7FFADCED7B9F1A2D  824A29E343A5543288BA1DCCC71BDF35
# 738830  B7EF8242FFE3369E40D0ED5FDDBB27B4  164B133FF8E8A8C7AE323DB990B37ADF
#
# ...

# %%
b.columns = ['medallion', 'hack_license', 'vendor_id', 'pickup_datetime',
       'payment_type', 'fare_amount', 'surcharge', 'mta_tax',
       'tip_amount', 'tolls_amount', 'total_amount']

# %%
b.columns
# Out:
# Index(['medallion', 'hack_license', 'vendor_id', 'pickup_datetime',
#        'payment_type', 'fare_amount', 'surcharge', 'mta_tax', 'tip_amount',
#        'tolls_amount', 'total_amount'],
#       dtype='object')

# %%
b
# Out:
#                                  medallion                      hack_license  \
# 0         89D227B655E5C82AECF13C3F540D4CF4  BA96DE419E711691B9445D6A6307C170
# 1         0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 2         0BD7C8F5BA12B88E0B67BED28BEA73D8  9FD8F69F0804BDB5549F40E9DA1BE472
# 3         DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# 4         DFD2202EE08F7A8DC9A57B02ACB81FE2  51EE87E3205C985EF8431D850C786310
# ...                                    ...                               ...
# 14776610  B33E71CD9E8FE1BE3B70FEB6E807DD15  BAF57796E45D921BB23217E17A372FF6
# 14776611  ED160B76D5349C8AC1ECF22CD4B8D538  3B93F6DA5DEBDE9560993FA624C4FF76
# 14776612  D83F9AC0E33F6F19869C243BE6AB6FE5  85A55B6772275374EF90AC9457DC1F83
# 14776613  04E59442A7DDBCE515E33CD355D866E7  7913172189931A1A1632562B10AB53C4
# 14776614  D30BED60331C79E3F7ACD05B325ED42F  B5E1D2461A5BCC8819188DACEC17CD69
#
# ...

# %%
c = a.merge(b, on=['medallion', 'hack_license', 'pickup_datetime', 'vendor_id'])

# %%
c.to_csv("all_data.csv", index=False)

# %%
vendor_id, pickup_datetime, dropoff_datetime, passenger_count, trip_time_in_secs, trip_distance, borought, payment_type,

# %%
c
# Out:
#                                medallion                      hack_license  \
# 0       4BAD9258F80F0557C351A1765B209298  44B47A8DA1F1543C803FFBFAB9A96412
# 1       EF0AE8B6BBD239B3424741BAB551C179  C12D7B322897E41D27B3981E036B2D47
# 2       4ECDC17413FB05BFDD0BA837C7D657EF  E39FFA7A2F91E5BD08B716832EA8112A
# 3       CA5B90CD7F0B61A0C32ABBCF3E1B1D73  A999EF8A46251492437FDA23C8F7DF3C
# 4       113D28C6EF6F520407B47F9C97580A3B  5852E74E3414B115D64C49B3D3ADB416
# ...                                  ...                               ...
# 738826  4591B5DD928BB1A9444B706425BECD8F  378F34F93043BC8CB5C92186819B2FD2
# 738827  40CE9601A3E4406427BC3799A4258CC7  63F78C93C7ABA820DE182CB864148191
# 738828  90444DF112C5770C8C82DE2A7930C69B  5594F56B961F941D7AE7AD5AB3C33442
# 738829  AA105C297823E6DA7FFADCED7B9F1A2D  824A29E343A5543288BA1DCCC71BDF35
# 738830  B7EF8242FFE3369E40D0ED5FDDBB27B4  164B133FF8E8A8C7AE323DB990B37ADF
#
# ...

# %%
set(c['vendor_id'].tolist())
# Out:
# {'CMT', 'VTS'}
